# %% [markdown]
# # Lectura y graficación de una señal almacenada en un archivo txt

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import re

# %% [markdown]
# ## Abrimos el archivo txt para ver  el contenido

# %%
f = open("señal ecg1.txt","r")
raw_data = f.readline()  # con f.read() leemos todo el contenido
f.close()

raw_data
# Out:
# 'Fs=100\n'

# %%
## Expresion regular para buscar automaticamente el contenido de un numero dentro de un string
x = re.findall("[0-5][0-9]\d", raw_data)

print(x)
# Out:
# ['100']

# %%
Fs = float(x[0])
Ts=1/Fs

print(f" Fs={Fs} hz\n Ts={Ts} s")
# Out:
#  Fs=100.0 hz
#  Ts=0.01 s

# %% [markdown]
# ## Leemos el archivo excluyendo las 2 primeras filas del archivo

# %%
array = np.genfromtxt("./señal ecg1.txt", delimiter=",",skip_header = 2)
array[:,1]= array[:,1] - np.mean(array[:,1])
array
# Out:
# array([[ 0.00000000e+00,  2.14464455e+01],
#        [ 1.00000000e-02,  2.54464455e+01],
#        [ 2.00000000e-02,  2.04464455e+01],
#        ...,
#        [ 9.49200000e+01, -9.55355450e+00],
#        [ 9.49300000e+01,  3.04464455e+01],
#        [ 9.49400000e+01, -8.55355450e+00]])

# %% [markdown]
# ## Ploteamos la lectura

# %%
def plotear(t0:float,tf:float,title:str):
    plt.figure().set_figwidth(15)
    plt.plot(array[:,0], array[:,1], label="señal")      # graficamos la señal
    plt.grid(linestyle=":")
    plt.xlabel("Tiempo (s)")
    plt.ylabel("Voltaje (mV)")
    plt.legend(loc="upper right")
    plt.xlim([t0,tf])
    plt.title(title)
    plt.show()

plotear(5,15,"Reposo basal")
plotear(35,45,"Ciclo de inhalación y exhalación con aguante de 5 segundos")
plotear(75,85,"Segundo reposo basal")

# %% [markdown]
# ## La forma de sabes la frecuencia de la señal es viendo en el dominio de la frecuencia

# %%
N = 2**10                                     # 10 bits, 0-1023

signal1 = array[:,1]

signal_fft = np.fft.fft(signal1, N)           # fft magtinud
signal_fft = np.round(np.abs(signal_fft),3)[0:N//2] # nos quedamos con los componente de la derecha de la FFT
signal_aux = signal_fft/signal_fft.max()     # hallamos el maximo para pasar la magnitud a escala db

with np.errstate(divide='ignore'):
    signal_fft_db = 10*np.log10(signal_aux)  # , out=signal_aux, where=signal_aux >= 0 para evitar division por zero

F_list = np.linspace(0,Fs/2, N//2)
F = np.round(F_list[np.argmax(signal_fft_db)], 1)   # argmax, encuentra el argumento max en un array

plt.plot(F_list, signal_fft_db)  #10 * np.log10(P / Pref) , decibelios
plt.text(F,0, f"{F}Hz")
plt.grid(linestyle=":")
plt.ylabel("Magnitud (db)")
plt.xlabel("Frecuencias (Hz)")
plt.title("FFT en el decibelios")
plt.xlim([0,50])
plt.xticks(np.arange(0,50,10))
plt.show()
