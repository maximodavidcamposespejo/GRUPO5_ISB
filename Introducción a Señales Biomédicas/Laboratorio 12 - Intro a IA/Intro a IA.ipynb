# %% [markdown]
# # Intro a IA

# %%
# Importamos librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# from sklearn.preprocessing import PolynomialFeatures    # unused import

# %%
# Extraemos datos
data='./para volumen 4ta vuelta.csv'

# %%
#visualizamos el dataset
df= pd.read_csv(data)
df.head()
# Out:
#     C  Rp  Dif_vol  V_in  V_out  P_ventilador   PIP  Error_aceptable
# 0  20  20     -2.7   350  352.7          27.6  25.5                1
# 1  20  20     -4.7   350  354.7          30.3  30.2                1
# 2  20  20      1.2   350  348.8          32.0  33.0                1
# 3  20  20      3.1   400  396.9          30.3  29.4                1
# 4  20  20     -7.0   400  407.0          33.9  34.3                1

# %%
#Revisamos dimension de la data
df.shape
# Out:
# (69, 8)

# %%
#filtramos decartando columnas con datos faltantes
d_filtrado = df.dropna().copy()

# %%
#Verificamos cuantos valores tenemos de Rp
d_filtrado.V_out.unique()
# Out:
# array([352.7, 354.7, 348.8, 396.9, 407. , 401.6, 442.2, 455.5, 451.2,
#        482.2, 492. , 494.5, 541.7, 549.6, 558.5, 597.3, 599. , 612.5,
#        327.8, 307.5, 303.2, 375. , 360.8, 358.6, 419.6, 408.8, 407.5,
#        455.2, 457.3, 461.5, 518.2, 515.8, 524.4, 574. , 571.6, 296.8,
#        281.3, 277.5, 335.2, 332.8, 330.7, 382. , 377. , 383. , 436.4,
#        429.6, 436.5, 498.1, 496.1, 499.6, 552. , 548.8, 269. , 302.6,
#        302.7, 303. , 344.1, 344.2, 389.1, 396.6, 386.5, 435.7, 452.7,
#        487.9, 509.7, 527. , 544.5, 559.9])

# %%
#revisamos de la data filtrada
d_filtrado.shape
# Out:
# (69, 8)

# %%
#contar valores
d_filtrado['Error_aceptable'].value_counts()
# Out:
# Error_aceptable
# 1    53
# 0    16
# Name: count, dtype: int64

# %%
#revisamos proporción
d_filtrado['Error_aceptable'].value_counts()/len(d_filtrado)
# Out:
# Error_aceptable
# 1    0.768116
# 0    0.231884
# Name: count, dtype: float64

# %%
#observamos el desbalance de datos
p=sns.catplot(data = d_filtrado, kind ='count', x= 'Error_aceptable')
p.set(title = "clases")

# %% [markdown]
# ## Dif_vol y P_ventilador

# %%
# definimos la matriz de caracteristicas
columnas=['Dif_vol','P_ventilador']

x = d_filtrado.loc[:,columnas]
y = d_filtrado['Error_aceptable']

# %%
print(len(y[y==0]))
print(len(y[y==1]))
# Out:
# 16
# 53

# %%
#divimos la data en conjunto de entranimiento y test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 0)
print(len(x_train),len(x_test))
# Out:
# 51 18

# %%
print(len(y_train[y_train==0]))
print(len(y_train[y_train==1]))
# Out:
# 11
# 40

# %%
# Estandarización de características
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)

# %%
print(df.head())
# Out:
#     C  Rp  Dif_vol  V_in  V_out  P_ventilador   PIP  Error_aceptable
# 0  20  20     -2.7   350  352.7          27.6  25.5                1
# 1  20  20     -4.7   350  354.7          30.3  30.2                1
# 2  20  20      1.2   350  348.8          32.0  33.0                1
# 3  20  20      3.1   400  396.9          30.3  29.4                1
# 4  20  20     -7.0   400  407.0          33.9  34.3                1

# %% [markdown]
# ### REGRESIÓN LOGISTICA

# %%
from sklearn.linear_model import LogisticRegression
regLog = LogisticRegression(random_state = 0)
regLog.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# Se anñade una columna constante para el término de intercepción
x_train_with_const = sm.add_constant(x_train)

# Crear un modelo logístico con statsmodels
logit_model = sm.Logit(y_train, x_train_with_const)

# Ajustar el modelo
result = logit_model.fit()

# Obtener los coeficientes y los p-valores
coefficients = result.params
p_values = result.pvalues

print("Coeficientes:")
print(coefficients)
print("\nP-valores:")
print(p_values)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.085406
#          Iterations 12
# Coeficientes:
# const    12.823493
# x1      -16.051232
# x2        4.479276
# dtype: float64
#
# P-valores:
# const    0.064688
# x1       0.062743
# x2       0.082921
# dtype: float64

# %%
score = regLog.score(x_test, y_test)
round(score,4)
# Out:
# 0.8889

# %%
y_pred = regLog.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       0.87      1.00      0.93        13
#
#     accuracy                           0.89        18
#    macro avg       0.93      0.80      0.84        18
# weighted avg       0.90      0.89      0.88        18

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 3  2]
#  [ 0 13]]

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0            0   1
# Error_aceptable
# 0                3   2
# 1                0  13

# %%
# K-fold cross validation
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = regLog, X = x_train, y=y_train, cv= 10)
accuracies.mean()
# Out:
# 0.9066666666666666

# %%
accuracies
# Out:
# array([0.66666667, 0.8       , 1.        , 0.8       , 1.        ,
#        1.        , 1.        , 0.8       , 1.        , 1.        ])

# %%
# Creamos un plot para ver la frontera de clasificación

from matplotlib.colors import ListedColormap
x_set, y_set = x_test, y_test
X1,X2 = np.meshgrid(np.arange(start = x_set[:,0].min()-1,stop = x_set[:,0].max()+1,step=0.01),
                    np.arange(start = x_set[:,1].min()-1,stop = x_set[:,0].max()+1,step=0.01))
plt.contourf(X1,X2, regLog.predict(np.array([X1.ravel(),X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap = ListedColormap(('magenta', 'cyan')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set == j,0],x_set[y_set== j,1],
                c = ListedColormap(('red','blue'))(i),label = j)
    
plt.title('Clasificador')
plt.xlabel(columnas[0])
plt.ylabel(columnas[1])
plt.legend()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25464\3656970026.py:12: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x_set[y_set == j,0],x_set[y_set== j,1],

# %% [markdown]
# ### **Balanceo ROS**

# %%
len(x_train)
# Out:
# 51

# %%
train = np.concatenate([x_train, y_train.values.reshape(-1,1)], axis=1)

# %%
#transformamos a un dataFrame
train = pd.DataFrame(train,columns=[*columnas,'Error_aceptable'])

# %%
#obtenemos la clase con error que no se acepta
train_class_0 = train.query("Error_aceptable == 0")
train_class_0.head()
# Out:
#      Dif_vol  P_ventilador  Error_aceptable
# 10  1.052039      0.223825              0.0
# 12  1.087821      0.960943              0.0
# 13  0.616145     -0.779474              0.0
# 16  1.953103     -1.363025              0.0
# 20  0.528316     -0.984229              0.0

# %%
train_class_0.shape
# Out:
# (11, 3)

# %%
n_class0 = len(train.query("Error_aceptable == 0"))
n_class1 = len(train.query("Error_aceptable == 1"))
print ( n_class0, n_class1)
# Out:
# 11 40

# %%
i_class0_downsampled = train_class_0.sample(n_class1,replace = True)
len(i_class0_downsampled)
# Out:
# 40

# %%
new_train = pd.concat([train.query("Error_aceptable == 1"), i_class0_downsampled], axis=0)
new_train[['Error_aceptable']].value_counts()
# Out:
# Error_aceptable
# 0.0                40
# 1.0                40
# Name: count, dtype: int64

# %%
new_x_train =new_train.loc[:,columnas].values
new_y_train =new_train.loc[:,['Error_aceptable']].values

# %%
new_y_train = pd.Series(new_y_train.reshape(-1,))

# %%
new_train.loc[:,['Error_aceptable']].value_counts()
# Out:
# Error_aceptable
# 0.0                40
# 1.0                40
# Name: count, dtype: int64

# %% [markdown]
# ### Nuevo modelo con nueva data

# %%
model= LogisticRegression()
model. fit(new_x_train, new_y_train)
# Out:
# LogisticRegression()

# %%
y_pred2 = model.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       0.87      1.00      0.93        13
#
#     accuracy                           0.89        18
#    macro avg       0.93      0.80      0.84        18
# weighted avg       0.90      0.89      0.88        18
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.85      0.92        13
#
#     accuracy                           0.89        18
#    macro avg       0.86      0.92      0.88        18
# weighted avg       0.92      0.89      0.89        18

# %% [markdown]
# ## P_ventilador y PIP

# %%
# definimos la matriz de caracteristicas
columnas=['V_out','P_ventilador']

x = d_filtrado.loc[:,columnas]
y = d_filtrado['Error_aceptable']

# %%
print(len(y[y==0]))
print(len(y[y==1]))
# Out:
# 16
# 53

# %%
#divimos la data en conjunto de entranimiento y test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 0)
print(len(x_train),len(x_test))
# Out:
# 51 18

# %%
print(len(y_train[y_train==0]))
print(len(y_train[y_train==1]))
# Out:
# 11
# 40

# %%
# Estandarización de características
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)

# %%
print(df.head())
# Out:
#     C  Rp  Dif_vol  V_in  V_out  P_ventilador   PIP  Error_aceptable
# 0  20  20     -2.7   350  352.7          27.6  25.5                1
# 1  20  20     -4.7   350  354.7          30.3  30.2                1
# 2  20  20      1.2   350  348.8          32.0  33.0                1
# 3  20  20      3.1   400  396.9          30.3  29.4                1
# 4  20  20     -7.0   400  407.0          33.9  34.3                1

# %% [markdown]
# ### REGRESIÓN LOGISTICA

# %%
from sklearn.linear_model import LogisticRegression
regLog = LogisticRegression(random_state = 0)
regLog.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# Se anñade una columna constante para el término de intercepción
x_train_with_const = sm.add_constant(x_train)

# Crear un modelo logístico con statsmodels
logit_model = sm.Logit(y_train, x_train_with_const)

# Ajustar el modelo
result = logit_model.fit()

# Obtener los coeficientes y los p-valores
coefficients = result.params
p_values = result.pvalues

print("Coeficientes:")
print(coefficients)
print("\nP-valores:")
print(p_values)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.331390
#          Iterations 8
# Coeficientes:
# const    2.447737
# x1       3.005791
# x2      -1.071492
# dtype: float64
#
# P-valores:
# const    0.000646
# x1       0.003465
# x2       0.170395
# dtype: float64

# %%
score = regLog.score(x_test, y_test)
round(score,4)
# Out:
# 0.7778

# %%
y_pred = regLog.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.33         5
#            1       0.76      1.00      0.87        13
#
#     accuracy                           0.78        18
#    macro avg       0.88      0.60      0.60        18
# weighted avg       0.83      0.78      0.72        18

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 1  4]
#  [ 0 13]]

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0            0   1
# Error_aceptable
# 0                1   4
# 1                0  13

# %%
# K-fold cross validation
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = regLog, X = x_train, y=y_train, cv= 10)
accuracies.mean()
# Out:
# 0.7666666666666667

# %%
accuracies
# Out:
# array([0.66666667, 0.4       , 0.8       , 0.8       , 1.        ,
#        0.6       , 0.8       , 0.8       , 0.8       , 1.        ])

# %%
# Creamos un plot para ver la frontera de clasificación

from matplotlib.colors import ListedColormap
x_set, y_set = x_test, y_test
X1,X2 = np.meshgrid(np.arange(start = x_set[:,0].min()-1,stop = x_set[:,0].max()+1,step=0.01),
                    np.arange(start = x_set[:,1].min()-1,stop = x_set[:,0].max()+1,step=0.01))
plt.contourf(X1,X2, regLog.predict(np.array([X1.ravel(),X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap = ListedColormap(('magenta', 'cyan')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set == j,0],x_set[y_set== j,1],
                c = ListedColormap(('red','blue'))(i),label = j)
    
plt.title('Clasificador')
plt.xlabel(columnas[0])
plt.ylabel(columnas[1])
plt.legend()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25464\3656970026.py:12: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x_set[y_set == j,0],x_set[y_set== j,1],

# %% [markdown]
# ### **Balanceo ROS**

# %%
len(x_train)
# Out:
# 51

# %%
train = np.concatenate([x_train, y_train.values.reshape(-1,1)], axis=1)

# %%
#transformamos a un dataFrame
train = pd.DataFrame(train,columns=[*columnas,'Error_aceptable'])

# %%
#obtenemos la clase con error que no se acepta
train_class_0 = train.query("Error_aceptable == 0")
train_class_0.head()
# Out:
#        V_out  P_ventilador  Error_aceptable
# 10 -0.994151      0.223825              0.0
# 12  0.061645      0.960943              0.0
# 13 -0.851101     -0.779474              0.0
# 16 -1.289859     -1.363025              0.0
# 20 -1.356046     -0.984229              0.0

# %%
train_class_0.shape
# Out:
# (11, 3)

# %%
n_class0 = len(train.query("Error_aceptable == 0"))
n_class1 = len(train.query("Error_aceptable == 1"))
print ( n_class0, n_class1)
# Out:
# 11 40

# %%
i_class0_downsampled = train_class_0.sample(n_class1,replace = True)
len(i_class0_downsampled)
# Out:
# 40

# %%
new_train = pd.concat([train.query("Error_aceptable == 1"), i_class0_downsampled], axis=0)
new_train[['Error_aceptable']].value_counts()
# Out:
# Error_aceptable
# 0.0                40
# 1.0                40
# Name: count, dtype: int64

# %%
new_x_train =new_train.loc[:,columnas].values
new_y_train =new_train.loc[:,['Error_aceptable']].values

# %%
new_y_train = pd.Series(new_y_train.reshape(-1,))

# %%
new_train.loc[:,['Error_aceptable']].value_counts()
# Out:
# Error_aceptable
# 0.0                40
# 1.0                40
# Name: count, dtype: int64

# %% [markdown]
# ### Nuevo modelo con nueva data

# %%
model= LogisticRegression()
model. fit(new_x_train, new_y_train)
# Out:
# LogisticRegression()

# %%
y_pred2 = model.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.33         5
#            1       0.76      1.00      0.87        13
#
#     accuracy                           0.78        18
#    macro avg       0.88      0.60      0.60        18
# weighted avg       0.83      0.78      0.72        18
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       1.00      0.92      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.92      0.96      0.93        18
# weighted avg       0.95      0.94      0.95        18
